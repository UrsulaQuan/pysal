# %%
# %load_ext autoreload
# %autoreload 2
import pysal as ps
import numpy as np
import json
from collection import Point, MultiPoint, LineString, MultiLineString
from collection import Polygon, MultiPolygon
from collection import FeatureCollection
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ps.examples.explain('columbus')
# Out:
# {'description': None, 'explanation': None, 'name': 'columbus'}

# %%
fp = ps.examples.get_path('columbus.json')
fc = FeatureCollection(fp)

# %%
f0 = fc.features[0]
f0['geometry'].rep_point
# Out:
# (8.829832553863525, 14.368754863739014)

# %%
fc.bbox
# Out:
# [5.87490701675415, 10.788629531860352, 11.287420272827148, 14.742449760437012]

# %%
fc.summary()
# Out:
# Coordinates:
#              min         max
# E        5.87491    11.28742
# N       10.78863    14.74245
#
# Number of features: 49
# Feature Type: Polygon
#
# Number of properties: 20
# PERIMETER           : <type 'float'>
# COLUMBUS_I          : <type 'float'>
# NEIGNO              : <type 'float'>
# POLYID              : <type 'float'>
# COLUMBUS_           : <type 'float'>
# NSA                 : <type 'float'>
# NSB                 : <type 'float'>
# AREA                : <type 'float'>
# HOVAL               : <type 'float'>
# NEIG                : <type 'int'>
# THOUS               : <type 'float'>
# CRIME               : <type 'float'>
# DISCBD              : <type 'float'>
# Y                   : <type 'float'>
# X                   : <type 'float'>
# EW                  : <type 'float'>
# CP                  : <type 'float'>
# OPEN                : <type 'float'>
# PLUMB               : <type 'float'>
# INC                 : <type 'float'>

# %%
fp = ps.examples.get_path('virginia.json')
fc = FeatureCollection(fp)

# %%
fc.summary()
# Out:
# Coordinates:
#              min         max
# E      -83.67526   -75.24258
# N       36.54148    39.45690
#
# Number of features: 136
# Feature Type: MultiPolygon
#
# Number of properties: 7
# STATE_NAME          : <type 'unicode'>
# CNTY_FIPS           : <type 'unicode'>
# STATE_FIPS          : <type 'unicode'>
# FIPS                : <type 'unicode'>
# Key                 : <type 'int'>
# POLY_ID             : <type 'int'>
# NAME                : <type 'unicode'>

# %%
fc.get_rep_points()
# Out:
# array([[-78.28526306,  39.23382187],
#        [-77.64323807,  39.08463478],
#        [-77.99277496,  39.12236977],
#        [-78.16913986,  39.17058563],
#        [-78.58446884,  38.85580063],
#        [-77.29192734,  38.84264374],
#        [-78.19631958,  38.8991127 ],
#        [-77.83676529,  38.71204567],
#        [-77.47426605,  38.72130013],
#        [-77.10844421,  38.88523674],
#        [-77.17255402,  38.87915421],
#        [-77.30796051,  38.84566307],
#        [-78.14195251,  38.69334602],
#        [-77.09044266,  38.81946564],
#        [-78.86080551,  38.52680779],
#        [-78.48295212,  38.62311172],
#        [-77.45405579,  38.77311707],
#        [-77.48745346,  38.7444706 ],
#        [-77.92578888,  38.5057373 ],
#        [-78.2741394 ,  38.42857933],
#        [-77.46266937,  38.41953468],
#        [-79.56011963,  38.38693237],
#        [-79.12672424,  38.1836834 ],
#        [-78.4730835 ,  38.32779884],
#        [-78.87410355,  38.42982292],
#        [-78.03948975,  38.25897026],
#        [-77.66427231,  38.18901253],
#        [-77.17667389,  38.26006508],
#        [-77.46776199,  38.28563499],
#        [-76.81089783,  38.12450981],
#        [-78.52334976,  38.00189018],
#        [-79.74882126,  38.05553055],
#        [-77.36079025,  38.01384926],
#        [-79.07735825,  38.14936829],
#        [-76.92542648,  37.94991493],
#        [-77.99773026,  37.94205666],
#        [-76.73027802,  37.95261955],
#        [-78.89030457,  38.06862068],
#        [-79.41263962,  37.81181717],
#        [-78.48748398,  38.03751373],
#        [-78.91743088,  37.78806114],
#        [-75.59184265,  37.74878502],
