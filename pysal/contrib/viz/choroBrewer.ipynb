# %%
import choroBrewer as cb
from pysal.contrib import pdio
import pysal as ps

# %%
gd = pdio.read_files(ps.examples.get_path('south.shp'))

# %%
cb.choro(gd, 'HR90')
reload(cb)

# %%
cb.choro(gd, 'HR90', show_cmaps=False, fig_size=(9,9))

# %%
cb.choro(gd, 'HR90',  fig_size=(7,7))
